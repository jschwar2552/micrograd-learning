# %% [markdown]
# # Python 101 Quiz
#
# Test what you learned! Write code in each cell, then run it to check.
#
# Use `%cc hint` if you're stuck on any question.

# %%
# %load_ext claude_code_jupyter
# Out:
# 🚀 Claude Code Magic loaded!
# Features:
#   • Full agentic Claude Code execution
#   • Cell-based code approval workflow
#   • Real-time message streaming
#   • Session state preservation
#   • Conversation continuity across cells
#
# Usage:
#   %cc <instructions>       # Continue with additional instructions (one-line)
#   %%cc <instructions>      # Continue with additional instructions (multi-line)
#   %cc_new (or %ccn)        # Start fresh conversation
#   %cc --help               # Show available options and usage information
#
# Context management:
#   %cc --import <file>       # Add a file to be included in initial conversation messages
#   %cc --add-dir <dir>       # Add a directory to Claude's accessible directories
#   %cc --mcp-config <file>   # Set path to a .mcp.json file containing MCP server configurations
#   %cc --cells-to-load <num> # The number of cells to load into a new conversation (default: all for first %cc, none for %cc_new)
#
# Output:
# ...

# %% [markdown]
# ---
# ## Q1: Variables
#
# Create a variable called `price` and set it to `49.99`

# %%
# Your code here:
name = "price"

# %%
price = 49.99

# %%
# Run this to check (should print True)
price == 49.99
# Out:
# True

# %% [markdown]
# ---
# ## Q2: Math
#
# What is 7 squared? (use `**`)

# %%
# Your code here (should output 49):
7**2
# Out:
# 49

# %% [markdown]
# ---
# ## Q3: Print with f-string
#
# Given `name = "Alex"` and `score = 95`, print: `Alex scored 95 points`

# %%
name = "Alex"
score = 95

# Your print statement here:
print(f"{name} scored {score} points")
# Out:
# Alex scored 95 points

# %% [markdown]
# ---
# ## Q4: Functions
#
# Create a function called `triple` that takes a number and returns it multiplied by 3.

# %%
# Your function here:
def triple(x):
    return x*3

# %%
# Run this to check (should print True, True, True)
print(triple(5) == 15)
print(triple(10) == 30)
print(triple(0) == 0)
# Out:
# True
# True
# True

# %% [markdown]
# ---
# ## Q5: Lists
#
# Create a list called `colors` with three items: `"red"`, `"green"`, `"blue"`

# %%
# Your code here:
colors = ["red", "green", "blue"]

# %%
# Run this to check (should print True)
colors == ["red", "green", "blue"]
# Out:
# True

# %% [markdown]
# ---
# ## Q6: List Access
#
# Get the SECOND item from `colors` (remember: counting starts at 0)

# %%
# Your code here (should output "green"):
colors[1]
# Out:
# 'green'

# %% [markdown]
# ---
# ## Q7: Loops
#
# Write a loop that prints each number in `[10, 20, 30]`

# %%
# Your loop here:
for n in [10,20,30]:
    print (n)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ---
# ## Q8: Loop + Math
#
# Write a loop that prints each number from 1 to 4, doubled.
#
# Expected output:
# ```
# 2
# 4
# 6
# 8
# ```

# %%
# Your loop here:
for n in [1,2,3,4]:
    print (n*2)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# ---
# ## Q9: Putting It Together
#
# Create a function called `sum_list` that takes a list of numbers and returns their total.
#
# Hint: You'll need a variable to keep track of the running total, and a loop.

# %%
# Your function here:
def sum_list:
    return
# Out:
#   Cell In[18], line 2
#     def sum_list
#                 ^
# SyntaxError: expected '('

# %%
# %cc can you help with Q9 im a bit confused
# Out:
# ✅ Continuing Claude session with execution results...
#
# ...
# 🤖 Claude wants to execute code
# ------------------------------------------------------------
# 📋 To approve: Run the cell below
# ➡️ To continue Claude agentically afterward: Run %cc
# ...
#
# 💭 Claude: I see you're asking about Q9 again. Let me provide the solution in a simpler way:
# ⏺ mcp__jupyter__create_python_cell
# 💭 Claude: This function adds up all the numbers in a list. Here's how it works:
#
# - `total = 0` - starts with zero
# - `for num in numbers:` - goes through each number in the list
# - `total += num` - adds each number to the total (same as `total = total + num`)
# - `return total` - gives back the final sum
#
# After you run this cell, there should be a test cell that checks if it works correctly (probably testing something like `sum_list([1,2,3,4])` which should equal 10).

# %%
# ╔════════════════════════════════════════════════════════════════════════════╗
# ║                        CLAUDE GENERATED CELL [id: ed995289-38c3-4593-bcd9-775d427a6bda]
# ╚════════════════════════════════════════════════════════════════════════════╝

# Your function here:
def sum_list(numbers):
    total = 0
    for num in numbers:
        total += num
    return total

# %%
# %cc --no-prompt-viz

# %%
# Run this to check (should print True, True)
print(sum_list([1, 2, 3]) == 6)
print(sum_list([10, 20, 30, 40]) == 100)

# %%
# %cc I'm stuck on Q9. How do I add up numbers in a loop?

# %% [markdown]
# ---
# ## Bonus: Predict the Output
#
# What will this print? Guess first, then run it.

# %%
x = 5
x = x + 1
x = x * 2
print(x)

# %% [markdown]
# ---
# ## Done!
#
# If you got 7+ correct, you're ready for `01_python_warmup.ipynb` (classes).
#
# If some were tricky, review `00_python_101.ipynb` and try again!
