# %% [markdown]
# # Setup & Test Claude Code Jupyter
#
# Run these cells to verify everything works before starting the micrograd journey.

# %%
# Load Claude Code Jupyter extension
# %load_ext claude_code_jupyter
# Out:
# 🚀 Claude Code Magic loaded!
# Features:
#   • Full agentic Claude Code execution
#   • Cell-based code approval workflow
#   • Real-time message streaming
#   • Session state preservation
#   • Conversation continuity across cells
#
# Usage:
#   %cc <instructions>       # Continue with additional instructions (one-line)
#   %%cc <instructions>      # Continue with additional instructions (multi-line)
#   %cc_new (or %ccn)        # Start fresh conversation
#   %cc --help               # Show available options and usage information
#
# Context management:
#   %cc --import <file>       # Add a file to be included in initial conversation messages
#   %cc --add-dir <dir>       # Add a directory to Claude's accessible directories
#   %cc --mcp-config <file>   # Set path to a .mcp.json file containing MCP server configurations
#   %cc --cells-to-load <num> # The number of cells to load into a new conversation (default: all for first %cc, none for %cc_new)
#
# Output:
# ...

# %%
# Test that core packages work
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)
y = x ** 2

plt.plot(x, y)
plt.title('y = x² (this is what we\'ll be taking derivatives of!)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
# Test Claude Code - ask it about the plot you just made!
# %cc What does this parabola represent? Why is understanding x² important for neural networks?
# Out:
# 📊 Conversation visualization enabled. Use %cc_viz to visualize this conversation on demand. Run %cc --no-prompt-viz to disable.
# 🧠 Claude model: claude-sonnet-4-5-20250929
# 💭 Claude: The parabola you're seeing represents **x²** - one of the most fundamental mathematical functions in machine learning and neural networks.
#
# ## What x² Represents
#
# This parabola shows a **quadratic function** where:
# - Every input x is squared to produce the output
# - It creates a smooth, symmetric U-shaped curve
# - The minimum point is at (0, 0)
# - It's always non-negative (y ≥ 0)
#
# ## Why x² Matters for Neural Networks
#
# **1. Non-linearity**
# - Neural networks need non-linear functions to learn complex patterns
# - Without non-linearity (like x²), stacking multiple layers would be pointless - it would collapse to just one linear transformation
# - x² is a simple example of how inputs map to outputs in a non-linear way
#
# **2. Gradient Behavior**
# ...

# %% [markdown]
# ---
# ## ✅ If everything above worked, you're ready!
#
# Next: Open `01_python_warmup.ipynb` to refresh Python concepts.
